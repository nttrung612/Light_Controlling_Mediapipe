# %%
import os
import cv2
import yaml
import torch
import numpy as np
import pandas as pd
from torch import nn
import mediapipe as mp
from torch import optim
from datetime import datetime
from torchmetrics import Accuracy
from torch.utils.data import Dataset

# %%
def label_dict_from_config_file(relative_path):
    with open(relative_path,"r") as f:
        label_tag = yaml.full_load(f)["gestures"]
    return label_tag

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        list_label = label_dict_from_config_file("hand_gesture.yaml")
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(63, 128),
            nn.ReLU(),
            nn.BatchNorm1d(128),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(p=0.4),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(p=0.4),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(p=0.6),
            nn.Linear(128, len(list_label)),
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

    def predict(self,x,threshold=0.8):
        logits = self(x)
        softmax_prob = nn.Softmax(dim=1)(logits)
        chosen_ind = torch.argmax(softmax_prob,dim=1)
        return torch.where(softmax_prob[0,chosen_ind]>threshold,chosen_ind,-1)

    def predict_with_known_class(self,x):
        logits = self(x)
        softmax_prob = nn.Softmax(dim=1)(logits)
        return torch.argmax(softmax_prob,dim=1)

    def score(self,logits):
        return -torch.amax(logits,dim=1)

# %%
class CustomImageDataset(Dataset):
    def __init__(self, data_file):
        self.data = pd.read_csv(data_file)
        self.labels = torch.from_numpy(self.data.iloc[:,0].to_numpy())

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        one_hot_label = self.labels[idx]
        torch_data = torch.from_numpy(self.data.iloc[idx,1:].to_numpy(dtype=np.float32))
        return torch_data, one_hot_label

# %%
class EarlyStopper:
    def __init__(self, patience=1, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.watched_metrics = np.inf

    def early_stop(self, current_value):
        if current_value < self.watched_metrics:
            self.watched_metrics = current_value
            self.counter = 0
        elif current_value > (self.watched_metrics + self.min_delta):
            self.counter += 1
            if self.counter >= self.patience:
                return True
        return False

# %%
def train(trainloader, val_loader, model, loss_function, early_stopper, optimizer):
    # add auroc score
    best_vloss = 1000000
    # timestamp = datetime.now().strftime('%d-%m %H:%M')
    for epoch in range(300):
        #training step
        model.train(True)
        running_loss = 0.0
        acc_train = Accuracy(num_classes=len(LIST_LABEL), task='MULTICLASS')
        for batch_number,data in enumerate(trainloader):
            inputs,labels = data
            optimizer.zero_grad()
            preds = model(inputs)
            loss = loss_function(preds,labels)
            loss.backward()
            optimizer.step()
            acc_train.update(model.predict_with_known_class(inputs), labels)
            running_loss += loss.item()
        avg_loss = running_loss / len(trainloader)
        # validating step
        model.train(False)
        running_vloss = 0.0
        acc_val = Accuracy(num_classes=len(LIST_LABEL), task='MULTICLASS')
        for i, vdata in enumerate(val_loader):
            vinputs, vlabels = vdata
            preds = model(vinputs)
            vloss = loss_function(preds, vlabels)
            running_vloss += vloss.item()
            acc_val.update(model.predict_with_known_class(vinputs), vlabels)

        # Log the running loss averaged per batch
        # for both training and validation
        print(f"Epoch {epoch}: ")
        print(f"Accuracy train:{acc_train.compute().item()}, val:{acc_val.compute().item()}")
        avg_vloss = running_vloss / len(val_loader)
        print('LOSS train {} valid {}'.format(avg_loss, avg_vloss))
        print('Training vs. Validation Loss',
              { 'Training' : avg_loss, 'Validation' : avg_vloss },
              epoch + 1)
        print('Training vs. Validation accuracy',
              { 'Training' : acc_train.compute().item()
                  , 'Validation' : acc_val.compute().item() },
              epoch + 1)

        # Track best performance, and save the model's state
        if avg_vloss < best_vloss:
            best_vloss = avg_vloss
            # best_model_path = f'./{save_path}/model_{timestamp}_{model.__class__.__name__}_best'
            best_model_path = f'./{save_path}/model_{model.__class__.__name__}_best'
            torch.save(model.state_dict(), best_model_path)
        if early_stopper.early_stop(avg_vloss):
            print(f"stopping at epoch {epoch}, minimum: {early_stopper.watched_metrics}")
            break

    # model_path = f'./{save_path}/model_{timestamp}_{model.__class__.__name__}_last'
    model_path = f'./{save_path}/model_{model.__class__.__name__}_last'
    torch.save(model.state_dict(), model_path)

    print(acc_val.compute())
    return model, best_model_path

# %%
DATA_FOLDER_PATH="./data/"
LIST_LABEL = label_dict_from_config_file("hand_gesture.yaml")
train_path = os.path.join(DATA_FOLDER_PATH,"landmark_train.csv")
val_path = os.path.join(DATA_FOLDER_PATH,"landmark_val.csv")
save_path = './models'
os.makedirs(save_path,exist_ok=True)

trainset = CustomImageDataset(train_path)
trainloader = torch.utils.data.DataLoader(trainset,batch_size=40,shuffle=True)

valset = CustomImageDataset(os.path.join(val_path))
val_loader = torch.utils.data.DataLoader(valset,batch_size=50, shuffle=False)

model = NeuralNetwork()
loss_function = nn.CrossEntropyLoss()
early_stopper = EarlyStopper(patience=30,min_delta=0.01)
optimizer = optim.Adam(model.parameters(),lr=0.0001)

model, best_model_path = train(trainloader, val_loader, model, loss_function, early_stopper, optimizer)
# Out:
# Epoch 0:
# Accuracy train:0.31639567017555237, val:0.5146948099136353
# LOSS train 1.5872046786385614 valid 1.5676347370500918
# Training vs. Validation Loss {'Training': 1.5872046786385614, 'Validation': 1.5676347370500918} 1
# Training vs. Validation accuracy {'Training': 0.31639567017555237, 'Validation': 0.5146948099136353} 1
# Epoch 1:
# Accuracy train:0.4464769661426544, val:0.5674453377723694
# LOSS train 1.5289028689667985 valid 1.4889736219688698
# Training vs. Validation Loss {'Training': 1.5289028689667985, 'Validation': 1.4889736219688698} 2
# Training vs. Validation accuracy {'Training': 0.4464769661426544, 'Validation': 0.5674453377723694} 2
# Epoch 2:
# Accuracy train:0.5718157291412354, val:0.6646571159362793
# LOSS train 1.412853988441261 valid 1.3298740916781955
# Training vs. Validation Loss {'Training': 1.412853988441261, 'Validation': 1.3298740916781955} 3
# Training vs. Validation accuracy {'Training': 0.5718157291412354, 'Validation': 0.6646571159362793} 3
# Epoch 3:
# Accuracy train:0.6612465977668762, val:0.7151469588279724
# LOSS train 1.2061326729284751 valid 1.0522918999195099
# Training vs. Validation Loss {'Training': 1.2061326729284751, 'Validation': 1.0522918999195099} 4
# Training vs. Validation accuracy {'Training': 0.6612465977668762, 'Validation': 0.7151469588279724} 4
# Epoch 4:
# Accuracy train:0.7771002650260925, val:0.7581009864807129
# LOSS train 0.9141764914667284 valid 0.7684028308700632
# Training vs. Validation Loss {'Training': 0.9141764914667284, 'Validation': 0.7684028308700632} 5
# Training vs. Validation accuracy {'Training': 0.7771002650260925, 'Validation': 0.7581009864807129} 5
# Epoch 5:
# Accuracy train:0.892276406288147, val:0.9909570217132568
# LOSS train 0.65820838792904 valid 0.45991622628989043
# Training vs. Validation Loss {'Training': 0.65820838792904, 'Validation': 0.45991622628989043} 6
# Training vs. Validation accuracy {'Training': 0.892276406288147, 'Validation': 0.9909570217132568} 6
# Epoch 6:
# Accuracy train:0.966802179813385, val:0.9992464184761047
# LOSS train 0.38979721149882757 valid 0.22252780488795704
# Training vs. Validation Loss {'Training': 0.38979721149882757, 'Validation': 0.22252780488795704} 7
# Training vs. Validation accuracy {'Training': 0.966802179813385, 'Validation': 0.9992464184761047} 7
# Epoch 7:
# Accuracy train:0.9884823560714722, val:0.9992464184761047
# LOSS train 0.22973568697233457 valid 0.11956086751349547
# Training vs. Validation Loss {'Training': 0.22973568697233457, 'Validation': 0.11956086751349547} 8
# Training vs. Validation accuracy {'Training': 0.9884823560714722, 'Validation': 0.9992464184761047} 8
# Epoch 8:
# Accuracy train:0.9979674816131592, val:0.9984928369522095
# LOSS train 0.13016488876294446 valid 0.05766178089780388
# Training vs. Validation Loss {'Training': 0.13016488876294446, 'Validation': 0.05766178089780388} 9
# Training vs. Validation accuracy {'Training': 0.9979674816131592, 'Validation': 0.9984928369522095} 9
# Epoch 9:
# Accuracy train:0.9952574372291565, val:0.9992464184761047
# LOSS train 0.08284038134120605 valid 0.032797005122389505
# Training vs. Validation Loss {'Training': 0.08284038134120605, 'Validation': 0.032797005122389505} 10
# Training vs. Validation accuracy {'Training': 0.9952574372291565, 'Validation': 0.9992464184761047} 10
# Epoch 10:
# Accuracy train:0.9993224740028381, val:0.996985673904419
# LOSS train 0.0573732633445714 valid 0.028063836033214575
# Training vs. Validation Loss {'Training': 0.0573732633445714, 'Validation': 0.028063836033214575} 11
# Training vs. Validation accuracy {'Training': 0.9993224740028381, 'Validation': 0.996985673904419} 11
# Epoch 11:
# Accuracy train:0.9979674816131592, val:1.0
# LOSS train 0.043043550506636906 valid 0.013595528913558357
# Training vs. Validation Loss {'Training': 0.043043550506636906, 'Validation': 0.013595528913558357} 12
# Training vs. Validation accuracy {'Training': 0.9979674816131592, 'Validation': 1.0} 12
# Epoch 12:
# Accuracy train:0.9959349632263184, val:1.0
# LOSS train 0.03040213097591658 valid 0.008684680603134135
# Training vs. Validation Loss {'Training': 0.03040213097591658, 'Validation': 0.008684680603134135} 13
# Training vs. Validation accuracy {'Training': 0.9959349632263184, 'Validation': 1.0} 13
# Epoch 13:
# Accuracy train:0.9993224740028381, val:1.0
# LOSS train 0.02785895442640459 valid 0.008437554477024134
# Training vs. Validation Loss {'Training': 0.02785895442640459, 'Validation': 0.008437554477024134} 14
# Training vs. Validation accuracy {'Training': 0.9993224740028381, 'Validation': 1.0} 14
# Epoch 14:
# Accuracy train:0.998645007610321, val:1.0
# LOSS train 0.025771505438496132 valid 0.005850555334257445
# Training vs. Validation Loss {'Training': 0.025771505438496132, 'Validation': 0.005850555334257445} 15
# Training vs. Validation accuracy {'Training': 0.998645007610321, 'Validation': 1.0} 15
# Epoch 15:
# Accuracy train:0.9979674816131592, val:1.0
# LOSS train 0.02139890334896139 valid 0.006007270571663631
# Training vs. Validation Loss {'Training': 0.02139890334896139, 'Validation': 0.006007270571663631} 16
# Training vs. Validation accuracy {'Training': 0.9979674816131592, 'Validation': 1.0} 16
# Epoch 16:
# Accuracy train:0.998645007610321, val:1.0
# LOSS train 0.015672043393793945 valid 0.003624342007377116
# Training vs. Validation Loss {'Training': 0.015672043393793945, 'Validation': 0.003624342007377116} 17
# Training vs. Validation accuracy {'Training': 0.998645007610321, 'Validation': 1.0} 17
# Epoch 17:
# Accuracy train:0.9993224740028381, val:1.0
# LOSS train 0.015426614422451806 valid 0.0028761255576952222
# Training vs. Validation Loss {'Training': 0.015426614422451806, 'Validation': 0.0028761255576952222} 18
# Training vs. Validation accuracy {'Training': 0.9993224740028381, 'Validation': 1.0} 18
# Epoch 18:
# Accuracy train:0.9993224740028381, val:1.0
# LOSS train 0.010415242022104762 valid 0.0017807724135410455
# Training vs. Validation Loss {'Training': 0.010415242022104762, 'Validation': 0.0017807724135410455} 19
# Training vs. Validation accuracy {'Training': 0.9993224740028381, 'Validation': 1.0} 19
# Epoch 19:
# Accuracy train:0.9993224740028381, val:1.0
# LOSS train 0.009718082064913737 valid 0.0024451989307568444
# Training vs. Validation Loss {'Training': 0.009718082064913737, 'Validation': 0.0024451989307568444} 20
# Training vs. Validation accuracy {'Training': 0.9993224740028381, 'Validation': 1.0} 20
# Epoch 20:
# Accuracy train:1.0, val:1.0
# LOSS train 0.010583538153032595 valid 0.002160448592702677
# Training vs. Validation Loss {'Training': 0.010583538153032595, 'Validation': 0.002160448592702677} 21
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 21
# Epoch 21:
# Accuracy train:1.0, val:1.0
# LOSS train 0.009685558380206695 valid 0.0028539307191682317
# Training vs. Validation Loss {'Training': 0.009685558380206695, 'Validation': 0.0028539307191682317} 22
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 22
# Epoch 22:
# Accuracy train:1.0, val:1.0
# LOSS train 0.007895586867439183 valid 0.001859306819824269
# Training vs. Validation Loss {'Training': 0.007895586867439183, 'Validation': 0.001859306819824269} 23
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 23
# Epoch 23:
# Accuracy train:0.9993224740028381, val:1.0
# LOSS train 0.007355478478948007 valid 0.001106867124488215
# Training vs. Validation Loss {'Training': 0.007355478478948007, 'Validation': 0.001106867124488215} 24
# Training vs. Validation accuracy {'Training': 0.9993224740028381, 'Validation': 1.0} 24
# Epoch 24:
# Accuracy train:1.0, val:1.0
# LOSS train 0.006559790904960922 valid 0.0011118666056130746
# Training vs. Validation Loss {'Training': 0.006559790904960922, 'Validation': 0.0011118666056130746} 25
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 25
# Epoch 25:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0056832753046340235 valid 0.001144192854755804
# Training vs. Validation Loss {'Training': 0.0056832753046340235, 'Validation': 0.001144192854755804} 26
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 26
# Epoch 26:
# Accuracy train:1.0, val:1.0
# LOSS train 0.005947363190038281 valid 0.0010748462439180541
# Training vs. Validation Loss {'Training': 0.005947363190038281, 'Validation': 0.0010748462439180541} 27
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 27
# Epoch 27:
# Accuracy train:0.9993224740028381, val:1.0
# LOSS train 0.004794388937109427 valid 0.001160236088725031
# Training vs. Validation Loss {'Training': 0.004794388937109427, 'Validation': 0.001160236088725031} 28
# Training vs. Validation accuracy {'Training': 0.9993224740028381, 'Validation': 1.0} 28
# Epoch 28:
# Accuracy train:1.0, val:1.0
# LOSS train 0.004934037146724861 valid 0.0011249894466884682
# Training vs. Validation Loss {'Training': 0.004934037146724861, 'Validation': 0.0011249894466884682} 29
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 29
# Epoch 29:
# Accuracy train:0.9993224740028381, val:1.0
# LOSS train 0.0038485063044857736 valid 0.0006530895665222219
# Training vs. Validation Loss {'Training': 0.0038485063044857736, 'Validation': 0.0006530895665222219} 30
# Training vs. Validation accuracy {'Training': 0.9993224740028381, 'Validation': 1.0} 30
# Epoch 30:
# Accuracy train:1.0, val:1.0
# LOSS train 0.004439023869250574 valid 0.000771918693317275
# Training vs. Validation Loss {'Training': 0.004439023869250574, 'Validation': 0.000771918693317275} 31
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 31
# Epoch 31:
# Accuracy train:0.9993224740028381, val:1.0
# LOSS train 0.00479081181677159 valid 0.001112819983333153
# Training vs. Validation Loss {'Training': 0.00479081181677159, 'Validation': 0.001112819983333153} 32
# Training vs. Validation accuracy {'Training': 0.9993224740028381, 'Validation': 1.0} 32
# Epoch 32:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.003490690086068384 valid 0.0014230278483140595
# Training vs. Validation Loss {'Training': 0.003490690086068384, 'Validation': 0.0014230278483140595} 33
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 33
# Epoch 33:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0030529604637932434 valid 0.0010827589732242712
# Training vs. Validation Loss {'Training': 0.0030529604637932434, 'Validation': 0.0010827589732242712} 34
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 34
# Epoch 34:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00372157700287455 valid 0.0007996344207236285
# Training vs. Validation Loss {'Training': 0.00372157700287455, 'Validation': 0.0007996344207236285} 35
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 35
# Epoch 35:
# Accuracy train:0.9993224740028381, val:1.0
# LOSS train 0.005552336107939482 valid 0.0008137413125816103
# Training vs. Validation Loss {'Training': 0.005552336107939482, 'Validation': 0.0008137413125816103} 36
# Training vs. Validation accuracy {'Training': 0.9993224740028381, 'Validation': 1.0} 36
# Epoch 36:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0032111030391329346 valid 0.0004964508789481881
# Training vs. Validation Loss {'Training': 0.0032111030391329346, 'Validation': 0.0004964508789481881} 37
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 37
# Epoch 37:
# Accuracy train:1.0, val:1.0
# LOSS train 0.002489537209102481 valid 0.0005206743308808318
# Training vs. Validation Loss {'Training': 0.002489537209102481, 'Validation': 0.0005206743308808318} 38
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 38
# Epoch 38:
# Accuracy train:1.0, val:1.0
# LOSS train 0.002093210686399362 valid 0.0006251940786249314
# Training vs. Validation Loss {'Training': 0.002093210686399362, 'Validation': 0.0006251940786249314} 39
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 39
# Epoch 39:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.0024441270738984836 valid 0.001041935344321448
# Training vs. Validation Loss {'Training': 0.0024441270738984836, 'Validation': 0.001041935344321448} 40
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 40
# Epoch 40:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0028346471863679237 valid 0.0005212614035675264
# Training vs. Validation Loss {'Training': 0.0028346471863679237, 'Validation': 0.0005212614035675264} 41
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 41
# Epoch 41:
# Accuracy train:1.0, val:1.0
# LOSS train 0.002263907910673879 valid 0.0007552886676152142
# Training vs. Validation Loss {'Training': 0.002263907910673879, 'Validation': 0.0007552886676152142} 42
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 42
# Epoch 42:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0018760830461286714 valid 0.0008349739205944692
# Training vs. Validation Loss {'Training': 0.0018760830461286714, 'Validation': 0.0008349739205944692} 43
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 43
# Epoch 43:
# Accuracy train:1.0, val:1.0
# LOSS train 0.002375408644061158 valid 0.00030014885892678985
# Training vs. Validation Loss {'Training': 0.002375408644061158, 'Validation': 0.00030014885892678985} 44
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 44
# Epoch 44:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0017833278177784302 valid 0.0002059286877687959
# Training vs. Validation Loss {'Training': 0.0017833278177784302, 'Validation': 0.0002059286877687959} 45
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 45
# Epoch 45:
# Accuracy train:1.0, val:1.0
# LOSS train 0.001410351090001043 valid 0.0005378334220890961
# Training vs. Validation Loss {'Training': 0.001410351090001043, 'Validation': 0.0005378334220890961} 46
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 46
# Epoch 46:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0018550251782447024 valid 0.0004456865903661209
# Training vs. Validation Loss {'Training': 0.0018550251782447024, 'Validation': 0.0004456865903661209} 47
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 47
# Epoch 47:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0012401660105506133 valid 0.000256970204721559
# Training vs. Validation Loss {'Training': 0.0012401660105506133, 'Validation': 0.000256970204721559} 48
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 48
# Epoch 48:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0009182850103447767 valid 0.0004128308506484178
# Training vs. Validation Loss {'Training': 0.0009182850103447767, 'Validation': 0.0004128308506484178} 49
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 49
# Epoch 49:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0014713096760395864 valid 0.00020806236214020323
# Training vs. Validation Loss {'Training': 0.0014713096760395864, 'Validation': 0.00020806236214020323} 50
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 50
# Epoch 50:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.0021223114682298555 valid 0.0027557100100658
# Training vs. Validation Loss {'Training': 0.0021223114682298555, 'Validation': 0.0027557100100658} 51
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 51
# Epoch 51:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.001349709534347435 valid 0.0027616866297635128
# Training vs. Validation Loss {'Training': 0.001349709534347435, 'Validation': 0.0027616866297635128} 52
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 52
# Epoch 52:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.0010700743687512178 valid 0.0017853882117040915
# Training vs. Validation Loss {'Training': 0.0010700743687512178, 'Validation': 0.0017853882117040915} 53
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 53
# Epoch 53:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0010079817281645799 valid 0.000810911879262398
# Training vs. Validation Loss {'Training': 0.0010079817281645799, 'Validation': 0.000810911879262398} 54
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 54
# Epoch 54:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.0013352398108926954 valid 0.0009786488863154671
# Training vs. Validation Loss {'Training': 0.0013352398108926954, 'Validation': 0.0009786488863154671} 55
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 55
# Epoch 55:
# Accuracy train:1.0, val:1.0
# LOSS train 0.001175820200571891 valid 0.000940703903165951
# Training vs. Validation Loss {'Training': 0.001175820200571891, 'Validation': 0.000940703903165951} 56
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 56
# Epoch 56:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0009334495792958281 valid 0.0009165211782807866
# Training vs. Validation Loss {'Training': 0.0009334495792958281, 'Validation': 0.0009165211782807866} 57
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 57
# Epoch 57:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.0007821885549158135 valid 0.0012813053478963722
# Training vs. Validation Loss {'Training': 0.0007821885549158135, 'Validation': 0.0012813053478963722} 58
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 58
# Epoch 58:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.0008537694626972331 valid 0.001489474229763935
# Training vs. Validation Loss {'Training': 0.0008537694626972331, 'Validation': 0.001489474229763935} 59
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 59
# Epoch 59:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.000893019575144265 valid 0.0011353966815035063
# Training vs. Validation Loss {'Training': 0.000893019575144265, 'Validation': 0.0011353966815035063} 60
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 60
# Epoch 60:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.0006834244586816813 valid 0.0010126858267332855
# Training vs. Validation Loss {'Training': 0.0006834244586816813, 'Validation': 0.0010126858267332855} 61
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 61
# Epoch 61:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.0004896262548140225 valid 0.0012231438620294401
# Training vs. Validation Loss {'Training': 0.0004896262548140225, 'Validation': 0.0012231438620294401} 62
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 62
# Epoch 62:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.0008319167104058874 valid 0.0008244618599096359
# Training vs. Validation Loss {'Training': 0.0008319167104058874, 'Validation': 0.0008244618599096359} 63
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 63
# Epoch 63:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.0009955732593142955 valid 0.0011859626756176495
# Training vs. Validation Loss {'Training': 0.0009955732593142955, 'Validation': 0.0011859626756176495} 64
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 64
# Epoch 64:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.0011872417125158717 valid 0.0011663814084580846
# Training vs. Validation Loss {'Training': 0.0011872417125158717, 'Validation': 0.0011663814084580846} 65
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 65
# Epoch 65:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.0007267856032027536 valid 0.0019221245212990455
# Training vs. Validation Loss {'Training': 0.0007267856032027536, 'Validation': 0.0019221245212990455} 66
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 66
# Epoch 66:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.0006896833245362457 valid 0.0006810160549719584
# Training vs. Validation Loss {'Training': 0.0006896833245362457, 'Validation': 0.0006810160549719584} 67
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 67
# Epoch 67:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.0008204784857839144 valid 0.0015594771555463478
# Training vs. Validation Loss {'Training': 0.0008204784857839144, 'Validation': 0.0015594771555463478} 68
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 68
# Epoch 68:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.0005660759351165915 valid 0.0017623862008192919
# Training vs. Validation Loss {'Training': 0.0005660759351165915, 'Validation': 0.0017623862008192919} 69
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 69
# Epoch 69:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.0005995707287110161 valid 0.0012123521994064942
# Training vs. Validation Loss {'Training': 0.0005995707287110161, 'Validation': 0.0012123521994064942} 70
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 70
# Epoch 70:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.0004501715099920418 valid 0.0018227671968219052
# Training vs. Validation Loss {'Training': 0.0004501715099920418, 'Validation': 0.0018227671968219052} 71
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 71
# Epoch 71:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.0004859517880135713 valid 0.0012955745108557003
# Training vs. Validation Loss {'Training': 0.0004859517880135713, 'Validation': 0.0012955745108557003} 72
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 72
# Epoch 72:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.001060187736780987 valid 0.002704348370466325
# Training vs. Validation Loss {'Training': 0.001060187736780987, 'Validation': 0.002704348370466325} 73
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 73
# Epoch 73:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0007787927062127966 valid 0.0005210045469397073
# Training vs. Validation Loss {'Training': 0.0007787927062127966, 'Validation': 0.0005210045469397073} 74
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 74
# Epoch 74:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.0004631074040623168 valid 0.0009327985936624815
# Training vs. Validation Loss {'Training': 0.0004631074040623168, 'Validation': 0.0009327985936624815} 75
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 75
# Epoch 75:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.0004489555896627182 valid 0.0008880678743794419
# Training vs. Validation Loss {'Training': 0.0004489555896627182, 'Validation': 0.0008880678743794419} 76
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 76
# Epoch 76:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.0005016006483659825 valid 0.000918179291735194
# Training vs. Validation Loss {'Training': 0.0005016006483659825, 'Validation': 0.000918179291735194} 77
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 77
# Epoch 77:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.0008310826666963072 valid 0.001344863233502025
# Training vs. Validation Loss {'Training': 0.0008310826666963072, 'Validation': 0.001344863233502025} 78
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 78
# Epoch 78:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0005610260021402044 valid 0.00035437728509232666
# Training vs. Validation Loss {'Training': 0.0005610260021402044, 'Validation': 0.00035437728509232666} 79
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 79
# Epoch 79:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0005688959994881156 valid 0.00015985744662884695
# Training vs. Validation Loss {'Training': 0.0005688959994881156, 'Validation': 0.00015985744662884695} 80
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 80
# Epoch 80:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.00040101715952718024 valid 0.0014128280644834287
# Training vs. Validation Loss {'Training': 0.00040101715952718024, 'Validation': 0.0014128280644834287} 81
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 81
# Epoch 81:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0005434986193191631 valid 0.0002161007636255691
# Training vs. Validation Loss {'Training': 0.0005434986193191631, 'Validation': 0.0002161007636255691} 82
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 82
# Epoch 82:
# Accuracy train:0.9993224740028381, val:0.9992464184761047
# LOSS train 0.00035616352879269225 valid 0.0005805068476094797
# Training vs. Validation Loss {'Training': 0.00035616352879269225, 'Validation': 0.0005805068476094797} 83
# Training vs. Validation accuracy {'Training': 0.9993224740028381, 'Validation': 0.9992464184761047} 83
# Epoch 83:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0006253364185426648 valid 0.00014309837941314693
# Training vs. Validation Loss {'Training': 0.0006253364185426648, 'Validation': 0.00014309837941314693} 84
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 84
# Epoch 84:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0003174740525512764 valid 0.0003634023357899003
# Training vs. Validation Loss {'Training': 0.0003174740525512764, 'Validation': 0.0003634023357899003} 85
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 85
# Epoch 85:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0005039482514532849 valid 5.028990802694958e-05
# Training vs. Validation Loss {'Training': 0.0005039482514532849, 'Validation': 5.028990802694958e-05} 86
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 86
# Epoch 86:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00028661873494530555 valid 0.0004133290724104535
# Training vs. Validation Loss {'Training': 0.00028661873494530555, 'Validation': 0.0004133290724104535} 87
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 87
# Epoch 87:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.0004978048538170107 valid 0.0020939366327727723
# Training vs. Validation Loss {'Training': 0.0004978048538170107, 'Validation': 0.0020939366327727723} 88
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 88
# Epoch 88:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.0005560117702230314 valid 0.0013787323406424111
# Training vs. Validation Loss {'Training': 0.0005560117702230314, 'Validation': 0.0013787323406424111} 89
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 89
# Epoch 89:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.00044235757800256453 valid 0.0008529926264365127
# Training vs. Validation Loss {'Training': 0.00044235757800256453, 'Validation': 0.0008529926264365127} 90
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 90
# Epoch 90:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.0006267845215621197 valid 0.0005840694037709116
# Training vs. Validation Loss {'Training': 0.0006267845215621197, 'Validation': 0.0005840694037709116} 91
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 91
# Epoch 91:
# Accuracy train:1.0, val:1.0
# LOSS train 0.000393537183717362 valid 5.193643586296646e-05
# Training vs. Validation Loss {'Training': 0.000393537183717362, 'Validation': 5.193643586296646e-05} 92
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 92
# Epoch 92:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0002746937732538484 valid 6.314052816749595e-05
# Training vs. Validation Loss {'Training': 0.0002746937732538484, 'Validation': 6.314052816749595e-05} 93
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 93
# Epoch 93:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00022093266289704007 valid 2.3201960436151864e-05
# Training vs. Validation Loss {'Training': 0.00022093266289704007, 'Validation': 2.3201960436151864e-05} 94
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 94
# Epoch 94:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00018649268788460568 valid 2.6101395010921687e-05
# Training vs. Validation Loss {'Training': 0.00018649268788460568, 'Validation': 2.6101395010921687e-05} 95
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 95
# Epoch 95:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00020794558682192055 valid 3.9327456192160705e-05
# Training vs. Validation Loss {'Training': 0.00020794558682192055, 'Validation': 3.9327456192160705e-05} 96
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 96
# Epoch 96:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0007278361083228594 valid 1.8781298425938917e-05
# Training vs. Validation Loss {'Training': 0.0007278361083228594, 'Validation': 1.8781298425938917e-05} 97
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 97
# Epoch 97:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0002877144149868007 valid 9.121580016876916e-06
# Training vs. Validation Loss {'Training': 0.0002877144149868007, 'Validation': 9.121580016876916e-06} 98
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 98
# Epoch 98:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00013890783692831237 valid 5.587756473112859e-06
# Training vs. Validation Loss {'Training': 0.00013890783692831237, 'Validation': 5.587756473112859e-06} 99
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 99
# Epoch 99:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00016331854438347463 valid 2.446971328883973e-05
# Training vs. Validation Loss {'Training': 0.00016331854438347463, 'Validation': 2.446971328883973e-05} 100
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 100
# Epoch 100:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0005395435032492183 valid 2.0393749871587902e-05
# Training vs. Validation Loss {'Training': 0.0005395435032492183, 'Validation': 2.0393749871587902e-05} 101
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 101
# Epoch 101:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00027023459760793894 valid 5.822787738288774e-05
# Training vs. Validation Loss {'Training': 0.00027023459760793894, 'Validation': 5.822787738288774e-05} 102
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 102
# Epoch 102:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.00057644190075882 valid 0.0008732026364320623
# Training vs. Validation Loss {'Training': 0.00057644190075882, 'Validation': 0.0008732026364320623} 103
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 103
# Epoch 103:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00020171629393730286 valid 0.00037714285853082983
# Training vs. Validation Loss {'Training': 0.00020171629393730286, 'Validation': 0.00037714285853082983} 104
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 104
# Epoch 104:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0002765246055934915 valid 0.00013647220956614493
# Training vs. Validation Loss {'Training': 0.0002765246055934915, 'Validation': 0.00013647220956614493} 105
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 105
# Epoch 105:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00032566966354204705 valid 0.00012045915069537051
# Training vs. Validation Loss {'Training': 0.00032566966354204705, 'Validation': 0.00012045915069537051} 106
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 106
# Epoch 106:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00045426204060522896 valid 0.00010880746382021564
# Training vs. Validation Loss {'Training': 0.00045426204060522896, 'Validation': 0.00010880746382021564} 107
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 107
# Epoch 107:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00018269353952475925 valid 0.0003553520718993858
# Training vs. Validation Loss {'Training': 0.00018269353952475925, 'Validation': 0.0003553520718993858} 108
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 108
# Epoch 108:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00024106894625219866 valid 0.0004293943933990712
# Training vs. Validation Loss {'Training': 0.00024106894625219866, 'Validation': 0.0004293943933990712} 109
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 109
# Epoch 109:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.0010435426053501597 valid 0.001775088603439951
# Training vs. Validation Loss {'Training': 0.0010435426053501597, 'Validation': 0.001775088603439951} 110
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 110
# Epoch 110:
# Accuracy train:0.9993224740028381, val:0.9992464184761047
# LOSS train 0.00016965708838953916 valid 0.0030562831170203924
# Training vs. Validation Loss {'Training': 0.00016965708838953916, 'Validation': 0.0030562831170203924} 111
# Training vs. Validation accuracy {'Training': 0.9993224740028381, 'Validation': 0.9992464184761047} 111
# Epoch 111:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.00022523929635246678 valid 0.002259035848791913
# Training vs. Validation Loss {'Training': 0.00022523929635246678, 'Validation': 0.002259035848791913} 112
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 112
# Epoch 112:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.0006595824895013007 valid 0.0015950947507071946
# Training vs. Validation Loss {'Training': 0.0006595824895013007, 'Validation': 0.0015950947507071946} 113
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 113
# Epoch 113:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.0003807480794372119 valid 0.001583453752362035
# Training vs. Validation Loss {'Training': 0.0003807480794372119, 'Validation': 0.001583453752362035} 114
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 114
# Epoch 114:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.00018262439258447753 valid 0.0009137667816961121
# Training vs. Validation Loss {'Training': 0.00018262439258447753, 'Validation': 0.0009137667816961121} 115
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 115
# Epoch 115:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0005794051961107176 valid 4.033506586200143e-05
# Training vs. Validation Loss {'Training': 0.0005794051961107176, 'Validation': 4.033506586200143e-05} 116
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 116
# Epoch 116:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.0004282077126255309 valid 0.0006487832827919262
# Training vs. Validation Loss {'Training': 0.0004282077126255309, 'Validation': 0.0006487832827919262} 117
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 117
# Epoch 117:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.0002931682446295462 valid 0.0007769788620404556
# Training vs. Validation Loss {'Training': 0.0002931682446295462, 'Validation': 0.0007769788620404556} 118
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 118
# Epoch 118:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00023757552303691596 valid 5.164855884316395e-05
# Training vs. Validation Loss {'Training': 0.00023757552303691596, 'Validation': 5.164855884316395e-05} 119
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 119
# Epoch 119:
# Accuracy train:0.9993224740028381, val:0.9992464184761047
# LOSS train 0.0008558003293814722 valid 0.0035549620371300903
# Training vs. Validation Loss {'Training': 0.0008558003293814722, 'Validation': 0.0035549620371300903} 120
# Training vs. Validation accuracy {'Training': 0.9993224740028381, 'Validation': 0.9992464184761047} 120
# Epoch 120:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.0004015475293591727 valid 0.0032091631359472705
# Training vs. Validation Loss {'Training': 0.0004015475293591727, 'Validation': 0.0032091631359472705} 121
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 121
# Epoch 121:
# Accuracy train:0.9993224740028381, val:0.9992464184761047
# LOSS train 0.0007446175098487623 valid 0.002990537658462047
# Training vs. Validation Loss {'Training': 0.0007446175098487623, 'Validation': 0.002990537658462047} 122
# Training vs. Validation accuracy {'Training': 0.9993224740028381, 'Validation': 0.9992464184761047} 122
# Epoch 122:
# Accuracy train:1.0, val:0.9977392554283142
# LOSS train 0.0004897427282697676 valid 0.005318899231916978
# Training vs. Validation Loss {'Training': 0.0004897427282697676, 'Validation': 0.005318899231916978} 123
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9977392554283142} 123
# Epoch 123:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.002068312364040262 valid 0.0011670752197353214
# Training vs. Validation Loss {'Training': 0.002068312364040262, 'Validation': 0.0011670752197353214} 124
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 124
# Epoch 124:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.0003001521461654291 valid 0.0015171254000693397
# Training vs. Validation Loss {'Training': 0.0003001521461654291, 'Validation': 0.0015171254000693397} 125
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 125
# Epoch 125:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.00025965272025869863 valid 0.0007798974094175458
# Training vs. Validation Loss {'Training': 0.00025965272025869863, 'Validation': 0.0007798974094175458} 126
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 126
# Epoch 126:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.00028510175360605826 valid 0.0012238488998455362
# Training vs. Validation Loss {'Training': 0.00028510175360605826, 'Validation': 0.0012238488998455362} 127
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 127
# Epoch 127:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0002032076889475787 valid 0.000289391162385939
# Training vs. Validation Loss {'Training': 0.0002032076889475787, 'Validation': 0.000289391162385939} 128
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 128
# Epoch 128:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0002995714339827041 valid 0.00034230081108607187
# Training vs. Validation Loss {'Training': 0.0002995714339827041, 'Validation': 0.00034230081108607187} 129
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 129
# Epoch 129:
# Accuracy train:1.0, val:0.9939713478088379
# LOSS train 0.00036699380576170077 valid 0.014690351048927443
# Training vs. Validation Loss {'Training': 0.00036699380576170077, 'Validation': 0.014690351048927443} 130
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9939713478088379} 130
# Epoch 130:
# Accuracy train:1.0, val:0.9962320923805237
# LOSS train 0.0001088735651973292 valid 0.006966439460644371
# Training vs. Validation Loss {'Training': 0.0001088735651973292, 'Validation': 0.006966439460644371} 131
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9962320923805237} 131
# Epoch 131:
# Accuracy train:1.0, val:0.9939713478088379
# LOSS train 0.0003289291785468113 valid 0.0114369204711658
# Training vs. Validation Loss {'Training': 0.0003289291785468113, 'Validation': 0.0114369204711658} 132
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9939713478088379} 132
# Epoch 132:
# Accuracy train:1.0, val:0.9954785108566284
# LOSS train 0.00014286603748808597 valid 0.007510684352707018
# Training vs. Validation Loss {'Training': 0.00014286603748808597, 'Validation': 0.007510684352707018} 133
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9954785108566284} 133
# Epoch 133:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.00017180357906147184 valid 0.0017087782548737818
# Training vs. Validation Loss {'Training': 0.00017180357906147184, 'Validation': 0.0017087782548737818} 134
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 134
# Epoch 134:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00029427266136317976 valid 0.0018908921441059782
# Training vs. Validation Loss {'Training': 0.00029427266136317976, 'Validation': 0.0018908921441059782} 135
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 135
# Epoch 135:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0001259740411913643 valid 0.0010524490957694156
# Training vs. Validation Loss {'Training': 0.0001259740411913643, 'Validation': 0.0010524490957694156} 136
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 136
# Epoch 136:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0005057590452833136 valid 0.002059541515395356
# Training vs. Validation Loss {'Training': 0.0005057590452833136, 'Validation': 0.002059541515395356} 137
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 137
# Epoch 137:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00013620181015527565 valid 0.0006276894249030667
# Training vs. Validation Loss {'Training': 0.00013620181015527565, 'Validation': 0.0006276894249030667} 138
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 138
# Epoch 138:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0002099954540242195 valid 0.001108936467054291
# Training vs. Validation Loss {'Training': 0.0002099954540242195, 'Validation': 0.001108936467054291} 139
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 139
# Epoch 139:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00028049489233003316 valid 0.000732963542864488
# Training vs. Validation Loss {'Training': 0.00028049489233003316, 'Validation': 0.000732963542864488} 140
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 140
# Epoch 140:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 6.955048776354808e-05 valid 0.0015019190761848195
# Training vs. Validation Loss {'Training': 6.955048776354808e-05, 'Validation': 0.0015019190761848195} 141
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 141
# Epoch 141:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0002421200406818546 valid 0.0003972481222118438
# Training vs. Validation Loss {'Training': 0.0002421200406818546, 'Validation': 0.0003972481222118438} 142
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 142
# Epoch 142:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00013351379715231815 valid 0.0012278797558163844
# Training vs. Validation Loss {'Training': 0.00013351379715231815, 'Validation': 0.0012278797558163844} 143
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 143
# Epoch 143:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0003455610491454462 valid 0.00034621903957859706
# Training vs. Validation Loss {'Training': 0.0003455610491454462, 'Validation': 0.00034621903957859706} 144
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 144
# Epoch 144:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 0.00010504931528455042 valid 0.000791261855599955
# Training vs. Validation Loss {'Training': 0.00010504931528455042, 'Validation': 0.000791261855599955} 145
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 145
# Epoch 145:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0004585429253899526 valid 3.791430489984714e-05
# Training vs. Validation Loss {'Training': 0.0004585429253899526, 'Validation': 3.791430489984714e-05} 146
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 146
# Epoch 146:
# Accuracy train:1.0, val:1.0
# LOSS train 6.802562333595651e-05 valid 0.0002500833435407038
# Training vs. Validation Loss {'Training': 6.802562333595651e-05, 'Validation': 0.0002500833435407038} 147
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 147
# Epoch 147:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0002414784455042438 valid 0.00012164439883480774
# Training vs. Validation Loss {'Training': 0.0002414784455042438, 'Validation': 0.00012164439883480774} 148
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 148
# Epoch 148:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0001320610686010499 valid 0.0004165386433857184
# Training vs. Validation Loss {'Training': 0.0001320610686010499, 'Validation': 0.0004165386433857184} 149
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 149
# Epoch 149:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00016013133931419115 valid 0.0003664556278360425
# Training vs. Validation Loss {'Training': 0.00016013133931419115, 'Validation': 0.0003664556278360425} 150
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 150
# Epoch 150:
# Accuracy train:1.0, val:1.0
# LOSS train 0.000598240071573818 valid 0.00026284047947651077
# Training vs. Validation Loss {'Training': 0.000598240071573818, 'Validation': 0.00026284047947651077} 151
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 151
# Epoch 151:
# Accuracy train:1.0, val:1.0
# LOSS train 6.77213824437294e-05 valid 0.0002731122502908408
# Training vs. Validation Loss {'Training': 6.77213824437294e-05, 'Validation': 0.0002731122502908408} 152
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 152
# Epoch 152:
# Accuracy train:1.0, val:1.0
# LOSS train 7.712751464070509e-05 valid 4.2945912030677315e-05
# Training vs. Validation Loss {'Training': 7.712751464070509e-05, 'Validation': 4.2945912030677315e-05} 153
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 153
# Epoch 153:
# Accuracy train:1.0, val:1.0
# LOSS train 9.64565945995108e-05 valid 0.0002641398837499916
# Training vs. Validation Loss {'Training': 9.64565945995108e-05, 'Validation': 0.0002641398837499916} 154
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 154
# Epoch 154:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 7.556440224918235e-05 valid 0.0009987341495108512
# Training vs. Validation Loss {'Training': 7.556440224918235e-05, 'Validation': 0.0009987341495108512} 155
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 155
# Epoch 155:
# Accuracy train:1.0, val:0.9992464184761047
# LOSS train 6.3740183227187e-05 valid 0.0012368789270291972
# Training vs. Validation Loss {'Training': 6.3740183227187e-05, 'Validation': 0.0012368789270291972} 156
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9992464184761047} 156
# Epoch 156:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00021708483806734776 valid 0.00013476950897133792
# Training vs. Validation Loss {'Training': 0.00021708483806734776, 'Validation': 0.00013476950897133792} 157
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 157
# Epoch 157:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00020240960024595452 valid 9.819579028756841e-05
# Training vs. Validation Loss {'Training': 0.00020240960024595452, 'Validation': 9.819579028756841e-05} 158
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 158
# Epoch 158:
# Accuracy train:1.0, val:1.0
# LOSS train 4.7598996573199384e-05 valid 0.00019463319959337846
# Training vs. Validation Loss {'Training': 4.7598996573199384e-05, 'Validation': 0.00019463319959337846} 159
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 159
# Epoch 159:
# Accuracy train:1.0, val:1.0
# LOSS train 7.409072238592548e-05 valid 0.00012951219039443102
# Training vs. Validation Loss {'Training': 7.409072238592548e-05, 'Validation': 0.00012951219039443102} 160
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 160
# Epoch 160:
# Accuracy train:1.0, val:1.0
# LOSS train 8.090739880891626e-05 valid 6.783688746820399e-05
# Training vs. Validation Loss {'Training': 8.090739880891626e-05, 'Validation': 6.783688746820399e-05} 161
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 161
# Epoch 161:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00010881403500975098 valid 0.00011725447303509337
# Training vs. Validation Loss {'Training': 0.00010881403500975098, 'Validation': 0.00011725447303509337} 162
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 162
# Epoch 162:
# Accuracy train:1.0, val:1.0
# ...
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 246
# Epoch 246:
# Accuracy train:1.0, val:1.0
# LOSS train 1.778419625003841e-05 valid 3.0216454194485096e-05
# Training vs. Validation Loss {'Training': 1.778419625003841e-05, 'Validation': 3.0216454194485096e-05} 247
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 247
# Epoch 247:
# Accuracy train:1.0, val:1.0
# LOSS train 2.7248232771376485e-05 valid 4.0299608301130475e-06
# Training vs. Validation Loss {'Training': 2.7248232771376485e-05, 'Validation': 4.0299608301130475e-06} 248
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 248
# Epoch 248:
# Accuracy train:1.0, val:1.0
# LOSS train 1.1360875795145913e-05 valid 0.00012094395614513107
# Training vs. Validation Loss {'Training': 1.1360875795145913e-05, 'Validation': 0.00012094395614513107} 249
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 249
# Epoch 249:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0001576745527337472 valid 0.00013055634533310756
# Training vs. Validation Loss {'Training': 0.0001576745527337472, 'Validation': 0.00013055634533310756} 250
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 250
# Epoch 250:
# Accuracy train:1.0, val:1.0
# LOSS train 1.0331296533995617e-05 valid 4.778612087689519e-05
# Training vs. Validation Loss {'Training': 1.0331296533995617e-05, 'Validation': 4.778612087689519e-05} 251
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 251
# Epoch 251:
# Accuracy train:1.0, val:0.9871891736984253
# LOSS train 0.0005268793955166191 valid 0.06431036542403813
# Training vs. Validation Loss {'Training': 0.0005268793955166191, 'Validation': 0.06431036542403813} 252
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9871891736984253} 252
# Epoch 252:
# Accuracy train:1.0, val:0.9932177662849426
# LOSS train 4.131718425871957e-05 valid 0.029307691917041963
# Training vs. Validation Loss {'Training': 4.131718425871957e-05, 'Validation': 0.029307691917041963} 253
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9932177662849426} 253
# Epoch 253:
# Accuracy train:1.0, val:0.9917106032371521
# LOSS train 1.1488151178939676e-05 valid 0.037510988464367206
# Training vs. Validation Loss {'Training': 1.1488151178939676e-05, 'Validation': 0.037510988464367206} 254
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9917106032371521} 254
# Epoch 254:
# Accuracy train:1.0, val:0.9939713478088379
# LOSS train 2.3771450709125935e-05 valid 0.02413514567251959
# Training vs. Validation Loss {'Training': 2.3771450709125935e-05, 'Validation': 0.02413514567251959} 255
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9939713478088379} 255
# Epoch 255:
# Accuracy train:1.0, val:0.9909570217132568
# LOSS train 1.8286949990371142e-05 valid 0.04155905086895539
# Training vs. Validation Loss {'Training': 1.8286949990371142e-05, 'Validation': 0.04155905086895539} 256
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9909570217132568} 256
# Epoch 256:
# Accuracy train:1.0, val:0.9939713478088379
# LOSS train 2.4249804039549866e-05 valid 0.024710286824468852
# Training vs. Validation Loss {'Training': 2.4249804039549866e-05, 'Validation': 0.024710286824468852} 257
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9939713478088379} 257
# Epoch 257:
# Accuracy train:1.0, val:0.9962320923805237
# LOSS train 1.3046656740757913e-05 valid 0.0071788749114451164
# Training vs. Validation Loss {'Training': 1.3046656740757913e-05, 'Validation': 0.0071788749114451164} 258
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9962320923805237} 258
# Epoch 258:
# Accuracy train:1.0, val:0.9939713478088379
# LOSS train 3.626019284196579e-05 valid 0.025884157961314647
# Training vs. Validation Loss {'Training': 3.626019284196579e-05, 'Validation': 0.025884157961314647} 259
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9939713478088379} 259
# Epoch 259:
# Accuracy train:1.0, val:0.9879427552223206
# LOSS train 2.722482169179105e-05 valid 0.0548056822622396
# Training vs. Validation Loss {'Training': 2.722482169179105e-05, 'Validation': 0.0548056822622396} 260
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9879427552223206} 260
# Epoch 260:
# Accuracy train:1.0, val:0.9954785108566284
# LOSS train 2.21964558278963e-05 valid 0.013099617481046957
# Training vs. Validation Loss {'Training': 2.21964558278963e-05, 'Validation': 0.013099617481046957} 261
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9954785108566284} 261
# Epoch 261:
# Accuracy train:1.0, val:0.9939713478088379
# LOSS train 1.8676694766907422e-05 valid 0.025740815873136005
# Training vs. Validation Loss {'Training': 1.8676694766907422e-05, 'Validation': 0.025740815873136005} 262
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9939713478088379} 262
# Epoch 262:
# Accuracy train:1.0, val:0.9962320923805237
# LOSS train 1.6098318639792155e-05 valid 0.009072643801077265
# Training vs. Validation Loss {'Training': 1.6098318639792155e-05, 'Validation': 0.009072643801077265} 263
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9962320923805237} 263
# Epoch 263:
# Accuracy train:1.0, val:0.9947249293327332
# LOSS train 3.3650316679813684e-05 valid 0.015256290028610908
# Training vs. Validation Loss {'Training': 3.3650316679813684e-05, 'Validation': 0.015256290028610908} 264
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9947249293327332} 264
# Epoch 264:
# Accuracy train:1.0, val:0.9977392554283142
# LOSS train 1.1526524778348846e-05 valid 0.007044128683867678
# Training vs. Validation Loss {'Training': 1.1526524778348846e-05, 'Validation': 0.007044128683867678} 265
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9977392554283142} 265
# Epoch 265:
# Accuracy train:1.0, val:0.9954785108566284
# LOSS train 1.4778080482771174e-05 valid 0.012964949619231612
# Training vs. Validation Loss {'Training': 1.4778080482771174e-05, 'Validation': 0.012964949619231612} 266
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9954785108566284} 266
# Epoch 266:
# Accuracy train:1.0, val:0.9939713478088379
# LOSS train 1.4909214975429237e-05 valid 0.01859108578929644
# Training vs. Validation Loss {'Training': 1.4909214975429237e-05, 'Validation': 0.01859108578929644} 267
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9939713478088379} 267
# Epoch 267:
# Accuracy train:1.0, val:0.9939713478088379
# LOSS train 6.247511170308549e-06 valid 0.018596650221262043
# Training vs. Validation Loss {'Training': 6.247511170308549e-06, 'Validation': 0.018596650221262043} 268
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9939713478088379} 268
# Epoch 268:
# Accuracy train:1.0, val:0.9947249293327332
# LOSS train 1.5094771731419791e-05 valid 0.01552422132185172
# Training vs. Validation Loss {'Training': 1.5094771731419791e-05, 'Validation': 0.01552422132185172} 269
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9947249293327332} 269
# Epoch 269:
# Accuracy train:1.0, val:0.9977392554283142
# LOSS train 4.759286936298871e-06 valid 0.005680568779081025
# Training vs. Validation Loss {'Training': 4.759286936298871e-06, 'Validation': 0.005680568779081025} 270
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9977392554283142} 270
# Epoch 270:
# Accuracy train:1.0, val:0.9939713478088379
# LOSS train 9.67642336500812e-05 valid 0.024290983297617415
# Training vs. Validation Loss {'Training': 9.67642336500812e-05, 'Validation': 0.024290983297617415} 271
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9939713478088379} 271
# Epoch 271:
# Accuracy train:1.0, val:0.9894498586654663
# LOSS train 0.001844223155777399 valid 0.04615934884689383
# Training vs. Validation Loss {'Training': 0.001844223155777399, 'Validation': 0.04615934884689383} 272
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9894498586654663} 272
# Epoch 272:
# Accuracy train:1.0, val:1.0
# LOSS train 1.3340931118584461e-05 valid 1.4465938834461333e-06
# Training vs. Validation Loss {'Training': 1.3340931118584461e-05, 'Validation': 1.4465938834461333e-06} 273
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 273
# Epoch 273:
# Accuracy train:1.0, val:1.0
# LOSS train 3.175212608426066e-05 valid 6.03893899985974e-06
# Training vs. Validation Loss {'Training': 3.175212608426066e-05, 'Validation': 6.03893899985974e-06} 274
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 274
# Epoch 274:
# Accuracy train:1.0, val:1.0
# LOSS train 7.17234953789806e-05 valid 7.548329535250136e-07
# Training vs. Validation Loss {'Training': 7.17234953789806e-05, 'Validation': 7.548329535250136e-07} 275
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 275
# Epoch 275:
# Accuracy train:1.0, val:1.0
# LOSS train 1.9721915302975628e-05 valid 2.546804336542205e-06
# Training vs. Validation Loss {'Training': 1.9721915302975628e-05, 'Validation': 2.546804336542205e-06} 276
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 276
# Epoch 276:
# Accuracy train:1.0, val:1.0
# LOSS train 2.343844351404556e-05 valid 7.555143257462102e-06
# Training vs. Validation Loss {'Training': 2.343844351404556e-05, 'Validation': 7.555143257462102e-06} 277
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 277
# Epoch 277:
# Accuracy train:1.0, val:1.0
# LOSS train 6.2048394817835316e-06 valid 4.4696280510481544e-07
# Training vs. Validation Loss {'Training': 6.2048394817835316e-06, 'Validation': 4.4696280510481544e-07} 278
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 278
# Epoch 278:
# Accuracy train:1.0, val:1.0
# LOSS train 7.581869699497152e-05 valid 7.364424438173324e-08
# Training vs. Validation Loss {'Training': 7.581869699497152e-05, 'Validation': 7.364424438173324e-08} 279
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 279
# Epoch 279:
# Accuracy train:1.0, val:1.0
# LOSS train 9.305497201335652e-06 valid 9.01994433475137e-06
# Training vs. Validation Loss {'Training': 9.305497201335652e-06, 'Validation': 9.01994433475137e-06} 280
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 280
# Epoch 280:
# Accuracy train:1.0, val:1.0
# LOSS train 3.709092832957326e-05 valid 3.943425201524275e-07
# Training vs. Validation Loss {'Training': 3.709092832957326e-05, 'Validation': 3.943425201524275e-07} 281
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 281
# Epoch 281:
# Accuracy train:1.0, val:1.0
# LOSS train 1.528129781704792e-05 valid 1.122159559151391e-06
# Training vs. Validation Loss {'Training': 1.528129781704792e-05, 'Validation': 1.122159559151391e-06} 282
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 282
# Epoch 282:
# Accuracy train:1.0, val:1.0
# LOSS train 2.2769803382530733e-05 valid 3.9010406393268645e-07
# Training vs. Validation Loss {'Training': 2.2769803382530733e-05, 'Validation': 3.9010406393268645e-07} 283
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 283
# Epoch 283:
# Accuracy train:1.0, val:1.0
# LOSS train 1.3700418783205685e-05 valid 8.904245518692733e-07
# Training vs. Validation Loss {'Training': 1.3700418783205685e-05, 'Validation': 8.904245518692733e-07} 284
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 284
# Epoch 284:
# Accuracy train:1.0, val:1.0
# LOSS train 1.614076376566865e-05 valid 4.5164352925876595e-07
# Training vs. Validation Loss {'Training': 1.614076376566865e-05, 'Validation': 4.5164352925876595e-07} 285
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 285
# Epoch 285:
# Accuracy train:1.0, val:1.0
# LOSS train 7.906329280856801e-06 valid 1.1689405111524486e-06
# Training vs. Validation Loss {'Training': 7.906329280856801e-06, 'Validation': 1.1689405111524486e-06} 286
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 286
# Epoch 286:
# Accuracy train:1.0, val:1.0
# LOSS train 3.0853115686315236e-06 valid 3.810095788170787e-07
# Training vs. Validation Loss {'Training': 3.0853115686315236e-06, 'Validation': 3.810095788170787e-07} 287
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 287
# Epoch 287:
# Accuracy train:1.0, val:1.0
# LOSS train 8.129519514070765e-06 valid 4.4769493939216744e-08
# Training vs. Validation Loss {'Training': 8.129519514070765e-06, 'Validation': 4.4769493939216744e-08} 288
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 288
# Epoch 288:
# Accuracy train:1.0, val:1.0
# LOSS train 9.30520541993781e-06 valid 3.9222153344106213e-07
# Training vs. Validation Loss {'Training': 9.30520541993781e-06, 'Validation': 3.9222153344106213e-07} 289
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 289
# Epoch 289:
# Accuracy train:1.0, val:1.0
# LOSS train 2.3702453961783398e-05 valid 1.9514958669606974e-08
# Training vs. Validation Loss {'Training': 2.3702453961783398e-05, 'Validation': 1.9514958669606974e-08} 290
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 290
# Epoch 290:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00010207113092884522 valid 1.607115586289688e-08
# Training vs. Validation Loss {'Training': 0.00010207113092884522, 'Validation': 1.607115586289688e-08} 291
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 291
# Epoch 291:
# Accuracy train:1.0, val:1.0
# LOSS train 2.344704918942507e-05 valid 1.577061044389228e-07
# Training vs. Validation Loss {'Training': 2.344704918942507e-05, 'Validation': 1.577061044389228e-07} 292
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 292
# Epoch 292:
# Accuracy train:1.0, val:1.0
# LOSS train 5.006454735774453e-05 valid 3.335940122987061e-07
# Training vs. Validation Loss {'Training': 5.006454735774453e-05, 'Validation': 3.335940122987061e-07} 293
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 293
# Epoch 293:
# Accuracy train:1.0, val:1.0
# LOSS train 3.0116603790111453e-05 valid 1.5152553236832648e-07
# Training vs. Validation Loss {'Training': 3.0116603790111453e-05, 'Validation': 1.5152553236832648e-07} 294
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 294
# Epoch 294:
# Accuracy train:1.0, val:1.0
# LOSS train 1.6727848792219857e-05 valid 1.0384335227100307e-07
# Training vs. Validation Loss {'Training': 1.6727848792219857e-05, 'Validation': 1.0384335227100307e-07} 295
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 295
# Epoch 295:
# Accuracy train:1.0, val:1.0
# LOSS train 2.45644493054759e-05 valid 7.337928475547739e-08
# Training vs. Validation Loss {'Training': 2.45644493054759e-05, 'Validation': 7.337928475547739e-08} 296
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 296
# Epoch 296:
# Accuracy train:1.0, val:1.0
# LOSS train 5.8268164871587315e-06 valid 2.351368304180594e-07
# Training vs. Validation Loss {'Training': 5.8268164871587315e-06, 'Validation': 2.351368304180594e-07} 297
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 297
# Epoch 297:
# Accuracy train:1.0, val:1.0
# LOSS train 1.0605143535071084e-05 valid 5.543196835207427e-07
# Training vs. Validation Loss {'Training': 1.0605143535071084e-05, 'Validation': 5.543196835207427e-07} 298
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 298
# Epoch 298:
# Accuracy train:1.0, val:1.0
# LOSS train 1.73144726419206e-05 valid 3.867662333610787e-08
# Training vs. Validation Loss {'Training': 1.73144726419206e-05, 'Validation': 3.867662333610787e-08} 299
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 299
# Epoch 299:
# Accuracy train:1.0, val:1.0
# LOSS train 5.026278646144763e-06 valid 6.552054301580925e-08
# Training vs. Validation Loss {'Training': 5.026278646144763e-06, 'Validation': 6.552054301580925e-08} 300
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 300
# tensor(1.)

# %%
list_label = label_dict_from_config_file("hand_gesture.yaml")
DATA_FOLDER_PATH="./data/"
testset = CustomImageDataset(os.path.join(DATA_FOLDER_PATH,"landmark_test.csv"))
test_loader = torch.utils.data.DataLoader(testset,batch_size=20,shuffle=False)

network = NeuralNetwork()
network.load_state_dict(torch.load(best_model_path, weights_only=False))

network.eval()
acc_test = Accuracy(num_classes=len(list_label), task='MULTICLASS')
for i, test_data in enumerate(test_loader):
    test_input, test_label = test_data
    preds = network(test_input)
    acc_test.update(preds, test_label)
print(network.__class__.__name__)
print(f"Accuracy of model:{acc_test.compute().item()}")
print("========================================================================")
# Out:
# NeuralNetwork
# Accuracy of model:0.9859050512313843
# ========================================================================

# %%
best_model_path
# Out:
# '././models/model_NeuralNetwork_best'
